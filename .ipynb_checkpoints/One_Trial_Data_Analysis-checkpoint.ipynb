# %%
import pandas as pd

# %%
df = pd.read_csv('processed/knot_tying/Knot_Tying_B001.csv')

# %%
df
# Out:
#       MASTER_LEFT_POS_X  MASTER_LEFT_POS_Y  MASTER_LEFT_POS_Z  \
# 0              0.111180          -0.033020           0.415991
# 1              0.111543          -0.032800           0.415891
# 2              0.112342          -0.032401           0.415759
# 3              0.113310          -0.032094           0.415662
# 4              0.114262          -0.031781           0.415619
# ...                 ...                ...                ...
# 1730           0.116785           0.036535           0.483924
# 1731           0.116884           0.036420           0.483817
# 1732           0.116952           0.036378           0.483691
# 1733           0.117057           0.036289           0.483460
# 1734           0.117186           0.036200           0.483347
#
#       MASTER_LEFT_ROT_R11  MASTER_LEFT_ROT_R12  MASTER_LEFT_ROT_R13  \
# 0               -0.421266             0.609012            -0.672075
# 1               -0.421579             0.608902            -0.671979
# ...

# %%
df.shape
# Out:
# (1735, 76)

# %%
df.info
# Out:
# <bound method DataFrame.info of       MASTER_LEFT_POS_X  MASTER_LEFT_POS_Y  MASTER_LEFT_POS_Z  \
# 0              0.111180          -0.033020           0.415991
# 1              0.111543          -0.032800           0.415891
# 2              0.112342          -0.032401           0.415759
# 3              0.113310          -0.032094           0.415662
# 4              0.114262          -0.031781           0.415619
# ...                 ...                ...                ...
# 1730           0.116785           0.036535           0.483924
# 1731           0.116884           0.036420           0.483817
# 1732           0.116952           0.036378           0.483691
# 1733           0.117057           0.036289           0.483460
# 1734           0.117186           0.036200           0.483347
#
#       MASTER_LEFT_ROT_R11  MASTER_LEFT_ROT_R12  MASTER_LEFT_ROT_R13  \
# 0               -0.421266             0.609012            -0.672075
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1735 entries, 0 to 1734
# Data columns (total 76 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MASTER_LEFT_POS_X           1735 non-null   float64
#  1   MASTER_LEFT_POS_Y           1735 non-null   float64
#  2   MASTER_LEFT_POS_Z           1735 non-null   float64
#  3   MASTER_LEFT_ROT_R11         1735 non-null   float64
#  4   MASTER_LEFT_ROT_R12         1735 non-null   float64
#  5   MASTER_LEFT_ROT_R13         1735 non-null   float64
#  6   MASTER_LEFT_ROT_R21         1735 non-null   float64
#  7   MASTER_LEFT_ROT_R22         1735 non-null   float64
#  8   MASTER_LEFT_ROT_R23         1735 non-null   float64
#  9   MASTER_LEFT_ROT_R31         1735 non-null   float64
#  10  MASTER_LEFT_ROT_R32         1735 non-null   float64
#  11  MASTER_LEFT_ROT_R33         1735 non-null   float64
#  12  MASTER_LEFT_LIN_VEL_X       1735 non-null   float64
# ...

# %%
pd.set_option("display.max_columns", 76)

# %%
result_knot_df = pd.read_csv("processed/trial_results/meta_file_Knot_Tying.csv")

# %%
result_knot_df
# Out:
#               trial self_skil  grs_score  tissue_respect  handling  \
# 0   Knot_Tying_B001         N         13               2         2
# 1   Knot_Tying_B002         N          9               1         1
# 2   Knot_Tying_B003         N         11               1         2
# 3   Knot_Tying_B004         N          8               1         2
# 4   Knot_Tying_C001         I         20               4         3
# 5   Knot_Tying_C002         I         22               4         3
# 6   Knot_Tying_C003         I         18               3         3
# 7   Knot_Tying_C004         I         20               4         3
# 8   Knot_Tying_C005         I         20               4         3
# 9   Knot_Tying_D001         E         14               3         1
# 10  Knot_Tying_D002         E         16               3         2
# 11  Knot_Tying_D003         E         12               1         2
# 12  Knot_Tying_D004         E         19               3         3
# ...

# %%
result_needle_df = pd.read_csv("processed/trial_results/meta_file_Needle_Passing.csv")

# %%
result_needle_df
# Out:
#                   trial self_skil  grs_score  tissue_respect  handling  \
# 0   Needle_Passing_B001         N          8               1         1
# 1   Needle_Passing_B002         N          8               1         1
# 2   Needle_Passing_B003         N         14               2         2
# 3   Needle_Passing_B004         N         19               3         3
# 4   Needle_Passing_C001         I         11               1         2
# 5   Needle_Passing_C002         I          9               1         1
# 6   Needle_Passing_C003         I          7               1         1
# 7   Needle_Passing_C004         I         12               1         2
# 8   Needle_Passing_C005         I         12               1         2
# 9   Needle_Passing_D001         E          9               1         1
# 10  Needle_Passing_D002         E         11               1         2
# 11  Needle_Passing_D003         E         10               1         2
# ...

# %%
result_suture_df = pd.read_csv("processed/trial_results/meta_file_Suturing.csv")
